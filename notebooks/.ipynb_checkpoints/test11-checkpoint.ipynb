# %%
#画像認識の実装
import os
# !unzip 'data/images_TMDU.zip' -d 'data/'
# Out:
# Archive:  data/images_TMDU.zip
#    creating: data/images/
#   inflating: data/__MACOSX/._images
#   inflating: data/images/.DS_Store
#   inflating: data/__MACOSX/images/._.DS_Store
#    creating: data/images/COVID-NORMAL/
#   inflating: data/__MACOSX/images/._COVID-NORMAL
#   inflating: data/images/test.jpg
#   inflating: data/__MACOSX/images/._test.jpg
#   inflating: data/images/covid.jpg
#   inflating: data/__MACOSX/images/._covid.jpg
#   inflating: data/images/NORMAL.jpg
#   inflating: data/__MACOSX/images/._NORMAL.jpg
#    creating: data/images/COVID-NORMAL/covid19/
#   inflating: data/__MACOSX/images/COVID-NORMAL/._covid19
#    creating: data/images/COVID-NORMAL/healthy/
#   inflating: data/__MACOSX/images/COVID-NORMAL/._healthy
#   inflating: data/images/COVID-NORMAL/covid19/DX.1.2.840.113564.1722810162.20200410172247966360.1203801020003.jpg
#   inflating: data/__MACOSX/images/COVID-NORMAL/covid19/._DX.1.2.840.113564.1722810162.20200410172247966360.1203801020003.jpg
# ...
